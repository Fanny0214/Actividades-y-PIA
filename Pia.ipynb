# %% [markdown]
# <a href="https://colab.research.google.com/github/Fanny0214/Actividades-y-PIA/blob/main/Pia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Jessica Marlene Alemán Amezcua #1729512
#
# Enrique Azael Páez Estrada #2063876 (N4)
#
# Stephanie Mariane Castillo Martínez #2054031
#
# Ashley Vanessa Cavazos Garza #2041543

# %%
#importar librerias
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
# Cargar la base
df = pd.read_csv('base_datos_semaforo.csv')

# %%
# Variables de entrada y salida
X = df[['autos_A', 'autos_B', 'autos_C', 'autos_D']]
y = df['calle_verde']

# %%
# Entrenar el árbol
modelo = DecisionTreeClassifier()
modelo.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
# Ver reglas aprendidas
plot_tree(modelo, feature_names=list(X.columns))
# Out:
# [Text(0.6666666666666666, 0.875, 'autos_B <= 4.5\ngini = 0.7\nsamples = 10\nvalue = [3, 4, 2, 1]'),
#  Text(0.5, 0.625, 'autos_A <= 5.0\ngini = 0.611\nsamples = 6\nvalue = [3, 0, 2, 1]'),
#  Text(0.5833333333333333, 0.75, 'True  '),
#  Text(0.3333333333333333, 0.375, 'autos_C <= 4.0\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1]'),
#  Text(0.16666666666666666, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.6666666666666666, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.8333333333333334, 0.625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]'),
#  Text(0.75, 0.75, '  False')]
